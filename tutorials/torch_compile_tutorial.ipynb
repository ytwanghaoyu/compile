# %%
# For tips on running notebooks in Google Colab, see
# https://docs.pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# Introduction to `torch.compile`
# ===============================
#
# **Author:** William Wen

# %% [markdown]
# `torch.compile` is the new way to speed up your PyTorch code!
# `torch.compile` makes PyTorch code run faster by JIT-compiling PyTorch
# code into optimized kernels, while requiring minimal code changes.
#
# `torch.compile` accomplishes this by tracing through your Python code,
# looking for PyTorch operations. Code that is difficult to trace will
# result a **graph break**, which are lost optimization opportunities,
# rather than errors or silent incorrectness.
#
# `torch.compile` is available in PyTorch 2.0 and later.
#
# This introduction covers basic `torch.compile` usage and demonstrates
# the advantages of `torch.compile` over our previous PyTorch compiler
# solution, [TorchScript](https://pytorch.org/docs/stable/jit.html).
#
# For an end-to-end example on a real model, check out our [end-to-end
# torch.compile
# tutorial](https://pytorch.org/tutorials/intermediate/torch_compile_full_example.html).
#
# To troubleshoot issues and to gain a deeper understanding of how to
# apply `torch.compile` to your code, check out [the torch.compile
# programming
# model](https://docs.pytorch.org/docs/stable/user_guide/torch_compiler/compile/programming_model.html).
#
# **Contents**
#
# ::: {.contents local=""}
# :::
#
# **Required pip dependencies for this tutorial**
#
# -   `torch >= 2.0`
# -   `numpy`
# -   `scipy`
#
# **System requirements** - A C++ compiler, such as `g++` - Python
# development package (`python-devel`/`python-dev`)

# %% [markdown]
# Basic Usage
# ===========
#
# We turn on some logging to help us to see what `torch.compile` is doing
# under the hood in this tutorial. The following code will print out the
# PyTorch ops that `torch.compile` traced.

# %%
import torch


torch._logging.set_logs(graph_code=True)

# %% [markdown]
# `torch.compile` is a decorator that takes an arbitrary Python function.

# %%
def foo(x, y):
    a = torch.sin(x)
    b = torch.cos(y)
    return a + b


opt_foo1 = torch.compile(foo)
print(opt_foo1(torch.randn(3, 3), torch.randn(3, 3)))
opt_foo1_dup = torch.compile(foo)
print(opt_foo1_dup(torch.randn(3, 3), torch.randn(3, 3)))

@torch.compile
def opt_foo2(x, y):
    a = torch.sin(x)
    b = torch.cos(y)
    return a + b


print(opt_foo2(torch.randn(3, 3), torch.randn(3, 3)))
# Out:
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code] TRACED GRAPH
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]  ===== __compiled_fn_1_b81d496b_749a_4d97_b5ad_cc9ffa194192 =====
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]     def forward(self, L_x_: "f32[3, 3][3, 1]cpu", L_y_: "f32[3, 3][3, 1]cpu"):
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         l_x_ = L_x_
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         l_y_ = L_y_
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:2 in foo, code: a = torch.sin(x)
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         a: "f32[3, 3][3, 1]cpu" = torch.sin(l_x_);  l_x_ = None
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:3 in foo, code: b = torch.cos(y)
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         b: "f32[3, 3][3, 1]cpu" = torch.cos(l_y_);  l_y_ = None
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:4 in foo, code: return a + b
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         add: "f32[3, 3][3, 1]cpu" = a + b;  a = b = None
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]         return (add,)
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]
# V0501 15:00:10.058000 8988 torch/_dynamo/output_graph.py:2184] [0/0] [__graph_code]
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code] TRACED GRAPH
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]  ===== __compiled_fn_3_4731d5e2_c919_40fb_a5ee_8c582b57b58d =====
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]     def forward(self, L_x_: "f32[3, 3][3, 1]cpu", L_y_: "f32[3, 3][3, 1]cpu"):
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         l_x_ = L_x_
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         l_y_ = L_y_
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:14 in opt_foo2, code: a = torch.sin(x)
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         a: "f32[3, 3][3, 1]cpu" = torch.sin(l_x_);  l_x_ = None
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:15 in opt_foo2, code: b = torch.cos(y)
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         b: "f32[3, 3][3, 1]cpu" = torch.cos(l_y_);  l_y_ = None
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         # File: /tmp/ipykernel_8988/1841589366.py:16 in opt_foo2, code: return a + b
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         add: "f32[3, 3][3, 1]cpu" = a + b;  a = b = None
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]         return (add,)
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]
# V0501 15:00:35.497000 8988 torch/_dynamo/output_graph.py:2184] [1/0] [__graph_code]
# tensor([[ 0.2549,  0.6078, -0.5492],
#         [-0.1646, -1.1006,  0.3785],
#         [ 1.8912,  1.4440,  0.9952]])
# tensor([[ 0.2778, -0.3513,  1.2172],
#         [ 1.8592,  1.5917, -0.7972],
#         [-1.3040,  1.4401,  0.0474]])
# tensor([[ 1.2072, -0.0202,  0.2798],
#         [ 1.1109,  0.1341,  0.9442],
#         [ 0.2357, -0.2598,  1.3117]])

# %% [markdown]
# `torch.compile` is applied recursively, so nested function calls within
# the top-level compiled function will also be compiled.

# %%
def inner(x):
    return torch.sin(x)


@torch.compile
def outer(x, y):
    a = inner(x)
    b = torch.cos(y)
    return a + b


print(outer(torch.randn(3, 3), torch.randn(3, 3)))
# Out:
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code] TRACED GRAPH
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]  ===== __compiled_fn_5_492cc90e_8dd0_4bc2_a1c8_9a3d4800660a =====
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]     def forward(self, L_x_: "f32[3, 3][3, 1]cpu", L_y_: "f32[3, 3][3, 1]cpu"):
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         l_x_ = L_x_
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         l_y_ = L_y_
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         # File: /tmp/ipykernel_8988/2199486826.py:2 in inner, code: return torch.sin(x)
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         a: "f32[3, 3][3, 1]cpu" = torch.sin(l_x_);  l_x_ = None
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         # File: /tmp/ipykernel_8988/2199486826.py:8 in outer, code: b = torch.cos(y)
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         b: "f32[3, 3][3, 1]cpu" = torch.cos(l_y_);  l_y_ = None
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         # File: /tmp/ipykernel_8988/2199486826.py:9 in outer, code: return a + b
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         add: "f32[3, 3][3, 1]cpu" = a + b;  a = b = None
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]         return (add,)
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]
# V0501 15:00:35.566000 8988 torch/_dynamo/output_graph.py:2184] [2/0] [__graph_code]
# tensor([[ 1.2619,  1.7793,  0.9895],
#         [-0.8576,  0.6139, -0.0067],
#         [ 0.2408,  0.5186,  0.9324]])

# %% [markdown]
# We can also optimize `torch.nn.Module` instances by either calling its
# `.compile()` method or by directly `torch.compile`-ing the module. This
# is equivalent to `torch.compile`-ing the module\'s `__call__` method
# (which indirectly calls `forward`).

# %%
t = torch.randn(10, 100)


class MyModule(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.lin = torch.nn.Linear(3, 3)

    def forward(self, x):
        return torch.nn.functional.relu(self.lin(x))


mod1 = MyModule()
mod1.compile()
print(mod1(torch.randn(3, 3)))

mod2 = MyModule()
mod2 = torch.compile(mod2)
print(mod2(torch.randn(3, 3)))
# Out:
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code] TRACED GRAPH
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]  ===== __compiled_fn_7_25e2f426_5619_454b_8617_3f78ec0ccbc7 =====
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]     def forward(self, L_self_modules_lin_parameters_weight_: "f32[3, 3][3, 1]cpu", L_self_modules_lin_parameters_bias_: "f32[3][1]cpu", L_x_: "f32[3, 3][3, 1]cpu"):
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         l_self_modules_lin_parameters_weight_ = L_self_modules_lin_parameters_weight_
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         l_self_modules_lin_parameters_bias_ = L_self_modules_lin_parameters_bias_
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         l_x_ = L_x_
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         # File: /tmp/ipykernel_8988/1755088953.py:10 in forward, code: return torch.nn.functional.relu(self.lin(x))
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         linear: "f32[3, 3][3, 1]cpu" = torch._C._nn.linear(l_x_, l_self_modules_lin_parameters_weight_, l_self_modules_lin_parameters_bias_);  l_x_ = l_self_modules_lin_parameters_weight_ = l_self_modules_lin_parameters_bias_ = None
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         relu: "f32[3, 3][3, 1]cpu" = torch.nn.functional.relu(linear);  linear = None
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]         return (relu,)
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]
# V0501 15:00:35.665000 8988 torch/_dynamo/output_graph.py:2184] [3/0] [__graph_code]
# tensor([[0.2232, 0.0000, 0.2041],
#         [0.7792, 0.1499, 0.0000],
#         [0.7864, 0.0000, 0.7014]], grad_fn=<CompiledFunctionBackward>)
# tensor([[0.3936, 0.0000, 0.0000],
#         [0.1373, 0.6629, 0.0000],
#         [1.5137, 0.0000, 0.6104]], grad_fn=<CompiledFunctionBackward>)

# %% [markdown]
# Demonstrating Speedups
# ======================
#
# Now let\'s demonstrate how `torch.compile` speeds up a simple PyTorch
# example. For a demonstration on a more complex model, see our
# [end-to-end torch.compile
# tutorial](https://pytorch.org/tutorials/intermediate/torch_compile_full_example.html).

# %%
def foo3(x):
    y = x + 1
    z = torch.nn.functional.relu(y)
    u = z * 2
    return u


opt_foo3 = torch.compile(foo3)


# Returns the result of running `fn()` and the time it took for `fn()` to run,
# in seconds. We use CUDA events and synchronization for the most accurate
# measurements.
def timed(fn):
    start = torch.cuda.Event(enable_timing=True)
    end = torch.cuda.Event(enable_timing=True)
    start.record()
    result = fn()
    end.record()
    torch.cuda.synchronize()
    return result, start.elapsed_time(end) / 1000


inp = torch.randn(4096, 4096).cuda()
print("compile:", timed(lambda: opt_foo3(inp))[1])
print("eager:", timed(lambda: foo3(inp))[1])
# Out:
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code] TRACED GRAPH
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]  ===== __compiled_fn_9_20fcc4e8_cdb7_450e_8a79_fe7c05f160b7 =====
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]     def forward(self, L_x_: "f32[4096, 4096][4096, 1]cuda:0"):
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         l_x_ = L_x_
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         # File: /tmp/ipykernel_8988/2208011240.py:2 in foo3, code: y = x + 1
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         y: "f32[4096, 4096][4096, 1]cuda:0" = l_x_ + 1;  l_x_ = None
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         # File: /tmp/ipykernel_8988/2208011240.py:3 in foo3, code: z = torch.nn.functional.relu(y)
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         z: "f32[4096, 4096][4096, 1]cuda:0" = torch.nn.functional.relu(y);  y = None
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         # File: /tmp/ipykernel_8988/2208011240.py:4 in foo3, code: u = z * 2
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         u: "f32[4096, 4096][4096, 1]cuda:0" = z * 2;  z = None
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]         return (u,)
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]
# V0501 15:01:13.264000 8988 torch/_dynamo/output_graph.py:2184] [4/0] [__graph_code]
# compile: 0.6047692260742188
# eager: 0.11675743865966796

# %% [markdown]
# ### 深入观察：查看生成的 Triton 代码
# 我们可以通过设置环境变量或使用 `torch._logging` 来打印 Inductor 生成的具体 GPU 代码（Triton 算子）。这能让我们看到原本的三个操作是如何被“融合”进一个循环里的。

# %%
import torch

# 清除之前的缓存以便重新生成日志
torch._dynamo.reset()

# 开启 inductor 日志，这样我们可以看到生成的 Triton 代码
torch._logging.set_logs(output_code=True)

def foo3(x):
    y = x + 1
    z = torch.nn.functional.relu(y)
    u = z * 2
    return u

opt_foo3 = torch.compile(foo3)
inp = torch.randn(1024, 1024, device='cuda')

print("--- 正在生成融合算子代码 ---")
# 第一次运行触发编译，日志会输出 Triton 代码
opt_foo3(inp)
print("--- 编译完成 ---")

torch._logging.set_logs(output_code=False)
# Out:
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] Output code:
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] # AOT ID: ['5_inference']
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from ctypes import c_void_p, c_long, c_int
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import torch
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import math
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import random
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import os
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import tempfile
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from math import inf, nan
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from cmath import nanj
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.hooks import run_intermediate_hooks
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.utils import maybe_profile
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.codegen.memory_planning import _align as align
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch import device, empty_strided
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.async_compile import AsyncCompile
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.select_algorithm import extern_kernels
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import triton
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import triton.language as tl
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.runtime.triton_heuristics import start_graph, end_graph
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._C import _cuda_getCurrentRawStream as get_raw_stream
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] aten = torch.ops.aten
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] inductor_ops = torch.ops.inductor
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] _quantized = torch.ops._quantized
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] assert_size_stride = torch._C._dynamo.guards.assert_size_stride
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] assert_alignment = torch._C._dynamo.guards.assert_alignment
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_cpu = torch._C._dynamo.guards._empty_strided_cpu
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_cpu_pinned = torch._C._dynamo.guards._empty_strided_cpu_pinned
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_cuda = torch._C._dynamo.guards._empty_strided_cuda
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_xpu = torch._C._dynamo.guards._empty_strided_xpu
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_mtia = torch._C._dynamo.guards._empty_strided_mtia
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] reinterpret_tensor = torch._C._dynamo.guards._reinterpret_tensor
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] alloc_from_pool = torch.ops.inductor._alloc_from_pool
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] async_compile = AsyncCompile()
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] empty_strided_p2p = torch._C._distributed_c10d._SymmetricMemory.empty_strided_p2p
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] # kernel path: /tmp/torchinductor_root/uz/cuz4hx3rvzfrqkhsuhpdidiemr5rvkqktigtaeaqk5orn6ojwqfv.py
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] # Topologically Sorted Source Nodes: [y, z, u], Original ATen: [aten.add, aten.relu, aten.mul]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] # Source node to ATen node mapping:
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   u => mul
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   y => add
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   z => relu
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] # Graph fragment:
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   %arg0_1 : Tensor "f32[1024, 1024][1024, 1]cuda:0" = PlaceHolder[target=arg0_1]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   %add : Tensor "f32[1024, 1024][1024, 1]cuda:0"[num_users=1] = call_function[target=torch.ops.aten.add.Tensor](args = (%arg0_1, 1), kwargs = {})
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   %relu : Tensor "f32[1024, 1024][1024, 1]cuda:0"[num_users=1] = call_function[target=torch.ops.aten.relu.default](args = (%add,), kwargs = {})
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   %mul : Tensor "f32[1024, 1024][1024, 1]cuda:0"[num_users=1] = call_function[target=torch.ops.aten.mul.Tensor](args = (%relu, 2), kwargs = {})
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] #   return %mul
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] triton_poi_fused_add_mul_relu_0 = async_compile.triton('triton_poi_fused_add_mul_relu_0', '''
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import triton
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] import triton.language as tl
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.runtime import triton_helpers, triton_heuristics
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.runtime.triton_helpers import libdevice, math as tl_math
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] from torch._inductor.runtime.hints import AutotuneHint, ReductionHint, TileHint, DeviceProperties
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] triton_helpers.set_driver_to_gpu()
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] @triton_heuristics.pointwise(
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     size_hints={'x': 1048576},
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     filename=__file__,
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     triton_meta={'signature': {'in_ptr0': '*fp32', 'out_ptr0': '*fp32', 'xnumel': 'i32', 'XBLOCK': 'constexpr'}, 'device': DeviceProperties(type='cuda', index=0, multi_processor_count=58, cc=89, major=8, regs_per_multiprocessor=65536, max_threads_per_multi_processor=1536, max_threads_per_block=1024, warp_size=32), 'constants': {}, 'native_matmul': False, 'configs': [{(0,): [['tt.divisibility', 16]], (1,): [['tt.divisibility', 16]], (2,): [['tt.divisibility', 16]]}], 'enable_fp_fusion': True},
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     inductor_meta={'grid_type': 'Grid1D', 'autotune_hints': set(), 'kernel_name': 'triton_poi_fused_add_mul_relu_0', 'mutated_arg_names': [], 'optimize_mem': True, 'no_x_dim': False, 'atomic_add_found': False, 'num_load': 1, 'num_store': 1, 'num_reduction': 0, 'backend_hash': 'ACCD7FD0B831EA5E92F974D478C3859F5347C1AD6F1C26F91DEF5B5012A2BEEF', 'assert_indirect_indexing': True, 'autotune_local_cache': True, 'autotune_pointwise': True, 'autotune_remote_cache': None, 'force_disable_caches': False, 'dynamic_scale_rblock': True, 'max_autotune': False, 'max_autotune_pointwise': False, 'min_split_scan_rblock': 256, 'spill_threshold': 16, 'store_cubin': False, 'deterministic': False, 'force_filter_reduction_configs': False, 'are_deterministic_algorithms_enabled': False, 'tiling_scores': {'x': 12582912}},
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     min_elem_per_thread=0
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] )
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] @triton.jit
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] def triton_poi_fused_add_mul_relu_0(in_ptr0, out_ptr0, xnumel, XBLOCK : tl.constexpr):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     xnumel = 1048576
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     xoffset = tl.program_id(0) * XBLOCK
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     xindex = xoffset + tl.arange(0, XBLOCK)[:]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     xmask = tl.full([XBLOCK], True, tl.int1)[:]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     x0 = xindex
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp0 = tl.load(in_ptr0 + (x0), None)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp1 = 1.0
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp2 = tmp0 + tmp1
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp3 = tl.full([1], 0, tl.int32)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp4 = triton_helpers.maximum(tmp3, tmp2)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp5 = 2.0
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tmp6 = tmp4 * tmp5
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     tl.store(out_ptr0 + (x0), tmp6, None)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] ''', device_str='cuda')
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] async_compile.wait(globals())
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] del async_compile
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] class Runner:
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     def __init__(self, partitions):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         self.partitions = partitions
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     def recursively_apply_fns(self, fns):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         new_callables = []
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         for fn, c in zip(fns, self.partitions):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             new_callables.append(fn(c))
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         self.partitions = new_callables
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     def call(self, args):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         arg0_1, = args
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         args.clear()
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         assert_size_stride(arg0_1, (1024, 1024), (1024, 1))
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         with torch.cuda._DeviceGuard(0):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             torch.cuda.set_device(0)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             buf0 = empty_strided_cuda((1024, 1024), (1024, 1), torch.float32)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             # Topologically Sorted Source Nodes: [y, z, u], Original ATen: [aten.add, aten.relu, aten.mul]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             stream0 = get_raw_stream(0)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             triton_poi_fused_add_mul_relu_0.run(arg0_1, buf0, 1048576, stream=stream0)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]             del arg0_1
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]         return (buf0, )
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] runner = Runner(partitions=[])
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] call = runner.call
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] recursively_apply_fns = runner.recursively_apply_fns
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] def benchmark_compiled_module(times=10, repeat=10):
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     from torch._dynamo.testing import rand_strided
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     from torch._inductor.utils import print_performance
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     arg0_1 = rand_strided((1024, 1024), (1024, 1), device='cuda:0', dtype=torch.float32)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     fn = lambda: call([arg0_1])
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     return print_performance(fn, times=times, repeat=repeat)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code] if __name__ == "__main__":
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     from torch._inductor.wrapper_benchmark import compiled_module_main
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]     compiled_module_main('None', benchmark_compiled_module)
# V0501 15:11:29.400000 8988 torch/_inductor/graph.py:2469] [0/0] [__output_code]
# V0501 15:11:29.403000 8988 torch/_inductor/graph.py:2480] [0/0] [__output_code] Output code written to: /tmp/torchinductor_root/7d/c7dldyhrqbjilkl6nlf6gempmvd2dxvd656owrm4w44vn3lnefma.py
# --- 正在生成融合算子代码 ---
# I0501 15:11:29.886000 8988 torch/_inductor/graph.py:2440] [0/0] [__output_code] Output code written to: /tmp/torchinductor_root/7d/c7dldyhrqbjilkl6nlf6gempmvd2dxvd656owrm4w44vn3lnefma.py
# --- 编译完成 ---

# %% [markdown]
# Notice that `torch.compile` appears to take a lot longer to complete
# compared to eager. This is because `torch.compile` takes extra time to
# compile the model on the first few executions. `torch.compile` re-uses
# compiled code whever possible, so if we run our optimized model several
# more times, we should see a significant improvement compared to eager.

# %%
# turn off logging for now to prevent spam
torch._logging.set_logs(graph_code=False)

eager_times = []
for i in range(10):
    _, eager_time = timed(lambda: foo3(inp))
    eager_times.append(eager_time)
    print(f"eager time {i}: {eager_time}")
print("~" * 10)

compile_times = []
for i in range(10):
    _, compile_time = timed(lambda: opt_foo3(inp))
    compile_times.append(compile_time)
    print(f"compile time {i}: {compile_time}")
print("~" * 10)

import numpy as np

eager_med = np.median(eager_times)
compile_med = np.median(compile_times)
speedup = eager_med / compile_med
assert speedup > 1
print(
    f"(eval) eager median: {eager_med}, compile median: {compile_med}, speedup: {speedup}x"
)
print("~" * 10)
# Out:
# eager time 0: 0.0020008959770202637
# eager time 1: 0.001972223997116089
# eager time 2: 0.0017817599773406983
# eager time 3: 0.0017592320442199707
# eager time 4: 0.0017612799406051636
# eager time 5: 0.001751039981842041
# eager time 6: 0.0017612799406051636
# eager time 7: 0.0017571840286254882
# eager time 8: 0.0017500159740447998
# eager time 9: 0.0017479679584503174
# ~~~~~~~~~~
# compile time 0: 0.0008038399815559387
# compile time 1: 0.0007157760262489318
# compile time 2: 0.0006656000018119813
# compile time 3: 0.0006666240096092224
# compile time 4: 0.0006502400040626526
# compile time 5: 0.0006584320068359376
# compile time 6: 0.0006533120274543762
# compile time 7: 0.0006584320068359376
# compile time 8: 0.0006563839912414551
# compile time 9: 0.0006604800224304199
# ~~~~~~~~~~
# (eval) eager median: 0.0017602559924125671, compile median: 0.0006594560146331787, speedup: 2.669254587649347x
# ~~~~~~~~~~

# %% [markdown]
# And indeed, we can see that running our model with `torch.compile`
# results in a significant speedup. Speedup mainly comes from reducing
# Python overhead and GPU read/writes, and so the observed speedup may
# vary on factors such as model architecture and batch size. For example,
# if a model\'s architecture is simple and the amount of data is large,
# then the bottleneck would be GPU compute and the observed speedup may be
# less significant.
#
# To see speedups on a real model, check out our [end-to-end torch.compile
# tutorial](https://pytorch.org/tutorials/intermediate/torch_compile_full_example.html).

# %% [markdown]
# Benefits over TorchScript
# =========================
#
# Why should we use `torch.compile` over TorchScript? Primarily, the
# advantage of `torch.compile` lies in its ability to handle arbitrary
# Python code with minimal changes to existing code.
#
# Compare to TorchScript, which has a tracing mode (`torch.jit.trace`) and
# a scripting mode (`torch.jit.script`). Tracing mode is susceptible to
# silent incorrectness, while scripting mode requires significant code
# changes and will raise errors on unsupported Python code.
#
# For example, TorchScript tracing silently fails on data-dependent
# control flow (the `if x.sum() < 0:` line below) because only the actual
# control flow path is traced. In comparison, `torch.compile` is able to
# correctly handle it.

# %%
def f1(x, y):
    if x.sum() < 0:
        return -y
    return y


# Test that `fn1` and `fn2` return the same result, given the same arguments `args`.
def test_fns(fn1, fn2, args):
    out1 = fn1(*args)
    out2 = fn2(*args)
    return torch.allclose(out1, out2)


inp1 = torch.randn(5, 5)
inp2 = torch.randn(5, 5)

traced_f1 = torch.jit.trace(f1, (inp1, inp2))
print("traced 1, 1:", test_fns(f1, traced_f1, (inp1, inp2)))
print("traced 1, 2:", test_fns(f1, traced_f1, (-inp1, inp2)))

compile_f1 = torch.compile(f1)
print("compile 1, 1:", test_fns(f1, compile_f1, (inp1, inp2)))
print("compile 1, 2:", test_fns(f1, compile_f1, (-inp1, inp2)))
print("~" * 10)
# Out:
# traced 1, 1: True
# traced 1, 2: False
# compile 1, 1: True
# compile 1, 2: True
# ~~~~~~~~~~
# /tmp/ipykernel_8988/65032246.py:2: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.sum() < 0:

# %% [markdown]
# TorchScript scripting can handle data-dependent control flow, but it can
# require major code changes and will raise errors when unsupported Python
# is used.
#
# In the example below, we forget TorchScript type annotations and we
# receive a TorchScript error because the input type for argument `y`, an
# `int`, does not match with the default argument type, `torch.Tensor`. In
# comparison, `torch.compile` works without requiring any type
# annotations.

# %%
import traceback as tb

torch._logging.set_logs(graph_code=True)


def f2(x, y):
    return x + y


inp1 = torch.randn(5, 5)
inp2 = 3

script_f2 = torch.jit.script(f2)
try:
    script_f2(inp1, inp2)
except:
    tb.print_exc()

compile_f2 = torch.compile(f2)
print("compile 2:", test_fns(f2, compile_f2, (inp1, inp2)))
print("~" * 10)
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_8988/3652677659.py", line 15, in <cell line: 0>
#     script_f2(inp1, inp2)
# RuntimeError: f2() Expected a value of type 'Tensor (inferred)' for argument 'y' but instead found type 'int'.
# Inferred 'y' to be of type 'Tensor' because it was not annotated with an explicit type.
# Position: 1
# Value: 3
# Declaration: f2(Tensor x, Tensor y) -> Tensor
# Cast error details: Unable to cast 3 to Tensor
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code] TRACED GRAPH
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]  ===== __compiled_fn_27_6ca2dae7_4ae0_4af4_b36b_4bfd0befc3a3 =====
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]     def forward(self, L_x_: "f32[5, 5][5, 1]cpu"):
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]         l_x_ = L_x_
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]         # File: /tmp/ipykernel_8988/3652677659.py:7 in f2, code: return x + y
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]         add: "f32[5, 5][5, 1]cpu" = l_x_ + 3;  l_x_ = None
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]         return (add,)
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]
# V0501 15:20:23.127000 8988 torch/_dynamo/output_graph.py:2184] [7/0] [__graph_code]
# compile 2: True
# ~~~~~~~~~~

# %% [markdown]
# Graph Breaks
# ============
#
# The graph break is one of the most fundamental concepts within
# `torch.compile`. It allows `torch.compile` to handle arbitrary Python
# code by interrupting compilation, running the unsupported code, then
# resuming compilation. The term \"graph break\" comes from the fact that
# `torch.compile` attempts to capture and optimize the PyTorch operation
# graph. When unsupported Python code is encountered, then this graph must
# be \"broken\". Graph breaks result in lost optimization opportunities,
# which may still be undesirable, but this is better than silent
# incorrectness or a hard crash.
#
# Let\'s look at a data-dependent control flow example to better see how
# graph breaks work.

# %%
def bar(a, b):
    x = a / (torch.abs(a) + 1)
    if b.sum() < 0:
        b = b * -1
    return x * b


opt_bar = torch.compile(bar)
inp1 = torch.ones(10)
inp2 = torch.ones(10)
opt_bar(inp1, inp2)
opt_bar(inp1, -inp2)
# Out:
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code] TRACED GRAPH
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]  ===== __compiled_fn_29_847f4b19_77fc_4c56_990d_af2731f12ad8 =====
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]     def forward(self, L_a_: "f32[10][1]cpu", L_b_: "f32[10][1]cpu"):
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         l_a_ = L_a_
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         l_b_ = L_b_
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         # File: /tmp/ipykernel_8988/49326488.py:2 in bar, code: x = a / (torch.abs(a) + 1)
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         abs_1: "f32[10][1]cpu" = torch.abs(l_a_)
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         add: "f32[10][1]cpu" = abs_1 + 1;  abs_1 = None
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         x: "f32[10][1]cpu" = l_a_ / add;  l_a_ = add = None
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         # File: /tmp/ipykernel_8988/49326488.py:3 in bar, code: if b.sum() < 0:
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         sum_1: "f32[][]cpu" = l_b_.sum();  l_b_ = None
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         lt: "b8[][]cpu" = sum_1 < 0;  sum_1 = None
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]         return (lt, x)
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]
# V0501 15:26:34.133000 8988 torch/_dynamo/output_graph.py:2184] [8/0] [__graph_code]
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code] TRACED GRAPH
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]  ===== __compiled_fn_33_a9de3bc1_5356_4793_bf41_2313b5934d85 =====
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]     def forward(self, L_x_: "f32[10][1]cpu", L_b_: "f32[10][1]cpu"):
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]         l_x_ = L_x_
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]         l_b_ = L_b_
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]         # File: /tmp/ipykernel_8988/49326488.py:5 in torch_dynamo_resume_in_bar_at_3, code: return x * b
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]         mul: "f32[10][1]cpu" = l_x_ * l_b_;  l_x_ = l_b_ = None
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]         return (mul,)
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]
# V0501 15:26:34.935000 8988 torch/_dynamo/output_graph.py:2184] [9/0] [__graph_code]
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code] TRACED GRAPH
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]  ===== __compiled_fn_35_5ae54d0b_c3ce_4554_b680_b2b89f024eab =====
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]  /usr/local/lib/python3.12/dist-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]     def forward(self, L_b_: "f32[10][1]cpu", L_x_: "f32[10][1]cpu"):
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         l_b_ = L_b_
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         l_x_ = L_x_
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         # File: /tmp/ipykernel_8988/49326488.py:4 in torch_dynamo_resume_in_bar_at_3, code: b = b * -1
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         b: "f32[10][1]cpu" = l_b_ * -1;  l_b_ = None
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         # File: /tmp/ipykernel_8988/49326488.py:5 in torch_dynamo_resume_in_bar_at_3, code: return x * b
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         mul_1: "f32[10][1]cpu" = l_x_ * b;  l_x_ = b = None
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]         return (mul_1,)
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]
# V0501 15:26:35.682000 8988 torch/_dynamo/output_graph.py:2184] [10/0] [__graph_code]
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000])

# %% [markdown]
# The first time we run `bar`, we see that `torch.compile` traced 2 graphs
# corresponding to the following code (noting that `b.sum() < 0` is
# False):
#
# 1.  `x = a / (torch.abs(a) + 1); b.sum()`
# 2.  `return x * b`
#
# The second time we run `bar`, we take the other branch of the if
# statement and we get 1 traced graph corresponding to the code
# `b = b * -1; return x * b`. We do not see a graph of
# `x = a / (torch.abs(a) + 1); b.sum()` outputted the second time since
# `torch.compile` cached this graph from the first run and re-used it.
#
# Let\'s investigate by example how TorchDynamo would step through `bar`.
# If `b.sum() < 0`, then TorchDynamo would run graph 1, let Python
# determine the result of the conditional, then run graph 2. On the other
# hand, if `not b.sum() < 0`, then TorchDynamo would run graph 1, let
# Python determine the result of the conditional, then run graph 3.
#
# We can see all graph breaks by using
# `torch._logging.set_logs(graph_breaks=True)`.

# %%
# Reset to clear the torch.compile cache
torch._dynamo.reset()

torch._logging.set_logs(graph_breaks=True)

opt_bar(inp1, inp2)
opt_bar(inp1, -inp2)

torch._logging.set_logs(graph_breaks=False)
# Out:
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks] Graph break in user code at /tmp/ipykernel_8988/49326488.py:3
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks] Graph Break Reason: Data-dependent branching
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   Explanation: Detected data-dependent branching (e.g. `if my_tensor.sum() > 0:`). Dynamo does not support tracing dynamic control flow.
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   Hint: This graph break is fundamental - it is unlikely that Dynamo will ever be able to trace through your code. Consider finding a workaround.
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   Hint: Use `torch.cond` to express dynamic control flow.
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   Developer debug context: attempted to jump with TensorVariable()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks] User code traceback:
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "<frozen runpy>", line 198, in _run_module_as_main
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "<frozen runpy>", line 88, in _run_code
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py", line 37, in <module>
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     ColabKernelApp.launch_instance()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/traitlets/config/application.py", line 992, in launch_instance
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     app.start()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelapp.py", line 712, in start
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     self.io_loop.start()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/tornado/platform/asyncio.py", line 211, in start
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     self.asyncio_loop.run_forever()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     self._run_once()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     handle._run()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     self._context.run(self._callback, *self._args)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     await self.process_one()
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     await dispatch(*args)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     await result
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     reply_content = await reply_content
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     res = shell.run_cell(
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     return super().run_cell(*args, **kwargs)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     result = self._run_cell(
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     return runner(coro)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     coro.send(None)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     if (await self.run_code(code, result,  async_=asy)):
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/tmp/ipykernel_8988/2940749256.py", line 6, in <cell line: 0>
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     opt_bar(inp1, inp2)
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]   File "/tmp/ipykernel_8988/49326488.py", line 3, in bar
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]     if b.sum() < 0:
# V0501 15:47:14.719000 8988 torch/_dynamo/symbolic_convert.py:4275] [0/0] [__graph_breaks]

# %% [markdown]
# In order to maximize speedup, graph breaks should be limited. We can
# force TorchDynamo to raise an error upon the first graph break
# encountered by using `fullgraph=True`:

# %%
# Reset to clear the torch.compile cache
torch._dynamo.reset()

opt_bar_fullgraph = torch.compile(bar, fullgraph=True)
try:
    opt_bar_fullgraph(torch.randn(10), torch.randn(10))
except:
    tb.print_exc()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_8988/387069252.py", line 6, in <cell line: 0>
#     opt_bar_fullgraph(torch.randn(10), torch.randn(10))
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 963, in compile_wrapper
#     raise e.with_traceback(None) from e.__cause__  # User compiler error
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch._dynamo.exc.Unsupported: Data-dependent branching
#   Explanation: Detected data-dependent branching (e.g. `if my_tensor.sum() > 0:`). Dynamo does not support tracing dynamic control flow.
#   Hint: This graph break is fundamental - it is unlikely that Dynamo will ever be able to trace through your code. Consider finding a workaround.
#   Hint: Use `torch.cond` to express dynamic control flow.
#
#   Developer debug context: attempted to jump with TensorVariable()
#
#  For more details about this graph break, please visit: https://meta-pytorch.github.io/compile-graph-break-site/gb/gb0170.html
#
# from user code:
#    File "/tmp/ipykernel_8988/49326488.py", line 3, in bar
#     if b.sum() < 0:
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"

# %% [markdown]
# In our example above, we can work around this graph break by replacing
# the if statement with a `torch.cond`:

# %%
from functorch.experimental.control_flow import cond


@torch.compile(fullgraph=True)
def bar_fixed(a, b):
    x = a / (torch.abs(a) + 1)

    def true_branch(y):
        return y * -1

    def false_branch(y):
        # NOTE: torch.cond doesn't allow aliased outputs
        return y.clone()

    b = cond(b.sum() < 0, true_branch, false_branch, (b,))
    return x * b


bar_fixed(inp1, inp2)
bar_fixed(inp1, -inp2)
# Out:
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000])

# %% [markdown]
# In order to serialize graphs or to run graphs on different (i.e.
# Python-less) environments, consider using `torch.export` instead (from
# PyTorch 2.1+). One important restriction is that `torch.export` does not
# support graph breaks. Please check [the torch.export
# tutorial](https://pytorch.org/tutorials/intermediate/torch_export_tutorial.html)
# for more details on `torch.export`.
#
# Check out our [section on graph breaks in the torch.compile programming
# model](https://docs.pytorch.org/docs/stable/user_guide/torch_compiler/compile/programming_model.graph_breaks_index.html)
# for tips on how to work around graph breaks.

# %% [markdown]
# Troubleshooting
# ===============
#
# Is `torch.compile` failing to speed up your model? Is compile time
# unreasonably long? Is your code recompiling excessively? Are you having
# difficulties dealing with graph breaks? Are you looking for tips on how
# to best use `torch.compile`? Or maybe you simply want to learn more
# about the inner workings of `torch.compile`?
#
# Check out [the torch.compile programming
# model](https://docs.pytorch.org/docs/stable/user_guide/torch_compiler/compile/programming_model.html).

# %% [markdown]
# Conclusion
# ==========
#
# In this tutorial, we introduced `torch.compile` by covering basic usage,
# demonstrating speedups over eager mode, comparing to TorchScript, and
# briefly describing graph breaks.
#
# For an end-to-end example on a real model, check out our [end-to-end
# torch.compile
# tutorial](https://pytorch.org/tutorials/intermediate/torch_compile_full_example.html).
#
# To troubleshoot issues and to gain a deeper understanding of how to
# apply `torch.compile` to your code, check out [the torch.compile
# programming
# model](https://docs.pytorch.org/docs/stable/user_guide/torch_compiler/compile/programming_model.html).
#
# We hope that you will give `torch.compile` a try!
